# %%
import pandas as pd
data = pd.read_csv("/Users/admin/Desktop/Test Prabh_cr_610_2019-12-16 (1).csv")

# %%
data.head()
# Out:
#   Campaign Id                                    Campaign Name  \
# 0                                                          NaN
# 1        2941                                     an_campaign4
# 2        4059      Recurring Campaign 18th Aug___20190101T0710
# 3        4060  New Recurring Campaign 18th Aug___20190101T0800
# 4        4062      Recurring Campaign 18th Aug___20190102T0716
#
#   Campaign Send Date (DD/MM/YYYY)  Total Contacts                From Email  \
# 0                             NaN             NaN                       NaN
# 1                01-01-2019 00:00           885.0  anants70000007@gmail.com
# 2                01-01-2019 07:10             5.0        recurring@team.com
# 3                01-01-2019 08:00             5.0        recurring@team.com
# 4                02-01-2019 07:16             5.0        recurring@team.com
#
#                                              Subject  Total Emails Sent  \
# ...

# %%
data.describe()
# Out:
#        Total Contacts  Total Emails Sent  Emails Delivered  Total Email Opens  \
# count      750.000000         751.000000        751.000000         751.000000
# mean         4.910667           9.557923          9.440746           2.508655
# std         32.414147         134.848524        133.304369          34.545925
# min          1.000000           0.000000        -41.000000           0.000000
# 25%          2.000000           1.000000          1.000000           0.000000
# 50%          3.000000           3.000000          3.000000           0.000000
# 75%          5.000000           5.000000          5.000000           1.000000
# max        885.000000        3589.000000       3545.000000         942.000000
#
#        Unique Email Opens  Total Email Clicks
# count          751.000000          751.000000
# mean             1.190413            0.247670
# std             16.314565            3.445177
# min              0.000000            0.000000
# ...

# %%
# Open HTML file in Jupyter
import requests
from bs4 import BeautifulSoup
page= requests.get("https://support.maropost.com/hc/en-us/articles/360015616374-Settings-Overview")
soup = BeautifulSoup(page.text)
txt = soup.get_text()
print(txt)
# Out:
# Settings Overview – Maropost
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#  })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# ga('create', 'UA-53205775-1', 'auto');
# ga('send', 'pageview');
#
#
#
#
#
# ...

# %%
git clone https://github.com/amueller/word_cloud.git
# Out:
#   File "<ipython-input-5-2f4e673c5277>", line 1
#     git clone https://github.com/amueller/word_cloud.git
#             ^
# SyntaxError: invalid syntax

# %%
data = pd.read_html(html_string)

# %%
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path
from PIL import Image

import matplotlib.pyplot as plt
% matplotlib inline

# %%
data[["Total Contacts", "Total Emails Sent","Total Email Clicks"]].describe()

# %%
# Groupby by country
country = data.groupby("Campaign Name")

# Summary statistic of all countries
country.describe().head()

# %%
country.mean().sort_values(by="Total Email Clicks",ascending=False).head()

# %%
plt.figure(figsize=(50,50))
country.mean().sort_values(by="Total Email Clicks",ascending=False).plot()
plt.xticks(rotation=50)
plt.xlabel("Country of Origin")
plt.ylabel("Number of Wines")
plt.show()

# %%
plt.figure(figsize=(15,10))
country.max().sort_values(by="Total Contacts",ascending=False)["Total Contacts"].plot.bar()
plt.xticks(rotation=50)
plt.xlabel("Country of Origin")
plt.ylabel("Highest point of Wines")
plt.show()

# %%
import seaborn as sns
import pandas as pd

plt.figure(figsize=(10,10)) 
# play with the figsize until the plot is big enough to plot all the columns
# of your dataset, or the way you desire it to look like otherwise

sns.heatmap(data.corr())

# %%
plt.figure(figsize=(10,10)) 
# play with the figsize until the plot is big enough to plot all the columns
# of your dataset, or the way you desire it to look like otherwise
data3 = data[["Total Contacts", "Total Emails Sent","Total Email Clicks"]]
sns.heatmap(data3.corr())

# %%
import matplotlib.pyplot as pPlot
from wordcloud import WordCloud, STOPWORDS
import numpy as npy
from PIL import Image
dataset = txt
def create_word_cloud(string):
   #maskArray = npy.array(Image.open("cloud.png"))
   cloud = WordCloud(background_color = "white", max_words = 200,stopwords = set(STOPWORDS))
   cloud.generate(string)
   cloud.to_file("/Users/admin/Desktop/gofullstack/wordCloud.png")
dataset = dataset.lower()
create_word_cloud(dataset)
from IPython.display import Image
Image("/Users/admin/Desktop/gofullstack/wordCloud.png")
